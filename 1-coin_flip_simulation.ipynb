# %%
# Fair Coin
from random import randrange
import matplotlib.pyplot as plt

# Store data for visualization
experiments = [100, 1000, 10000, 100000]
heads_counts = []
tails_counts = []

for experiment in experiments:
    heads = tails = 0
    for i in range(experiment):
        if randrange(2) == 0:
            heads += 1
        else:
            tails += 1
    heads_counts.append(heads)
    tails_counts.append(tails)
    print("experiment:", experiment)
    print("heads =", heads, "  tails =", tails)
    print("the ratio of #heads/#tails is", round(heads / tails, 4))
    print()

# Plotting the bar graph
x = range(len(experiments))  # [0, 1, 2, 3]
bar_width = 0.35

plt.bar([i - bar_width/2 for i in x], heads_counts, width=bar_width, label='Heads', color='skyblue')
plt.bar([i + bar_width/2 for i in x], tails_counts, width=bar_width, label='Tails', color='salmon')

plt.xticks(x, [str(e) for e in experiments])
plt.xlabel('Number of Coin Flips')
plt.ylabel('Count')
plt.title('Heads vs Tails in Coin Toss Experiments')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# experiment: 100
# heads = 56   tails = 44
# the ratio of #heads/#tails is 1.2727
#
# experiment: 1000
# heads = 474   tails = 526
# the ratio of #heads/#tails is 0.9011
#
# experiment: 10000
# heads = 5042   tails = 4958
# the ratio of #heads/#tails is 1.0169
#
# experiment: 100000
# heads = 50009   tails = 49991
# the ratio of #heads/#tails is 1.0004

# %%
# Un_Fair Coin
from random import randrange
import matplotlib.pyplot as plt

# Store data for visualization
experiments = [100, 1000, 10000, 100000]
heads_counts = []
tails_counts = []

for experiment in experiments:
    heads = tails = 0
    for i in range(experiment):
        if randrange(101) > 70:
            heads += 1
        else:
            tails += 1
    heads_counts.append(heads)
    tails_counts.append(tails)
    print("experiment:", experiment)
    print("heads =", heads, "  tails =", tails)
    print("the ratio of #heads/#tails is", round(heads / tails, 4))
    print()

# Plotting the bar graph
x = range(len(experiments))  # [0, 1, 2, 3]
bar_width = 0.35

plt.bar([i - bar_width/2 for i in x], heads_counts, width=bar_width, label='Heads', color='skyblue')
plt.bar([i + bar_width/2 for i in x], tails_counts, width=bar_width, label='Tails', color='salmon')

plt.xticks(x, [str(e) for e in experiments])
plt.xlabel('Number of Coin Flips')
plt.ylabel('Count')
plt.title('Heads vs Tails in Coin Toss Experiments')
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# experiment: 100
# heads = 33   tails = 67
# the ratio of #heads/#tails is 0.4925
#
# experiment: 1000
# heads = 291   tails = 709
# the ratio of #heads/#tails is 0.4104
#
# experiment: 10000
# heads = 2911   tails = 7089
# the ratio of #heads/#tails is 0.4106
#
# experiment: 100000
# heads = 29742   tails = 70258
# the ratio of #heads/#tails is 0.4233

# %%
randrange(55)
# Out:
# 31
